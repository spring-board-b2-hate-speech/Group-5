# %%
pwd
# Out:
# 'C:\\Users\\suman\\Contacts\\hatespeechfolder\\project'

# %%
#Importing the packages
import pandas as pd
import numpy as np
from sklearn. feature_extraction. text import CountVectorizer
from sklearn. model_selection import train_test_split
from sklearn. tree import DecisionTreeClassifier
import nltk
import re
#nltk. download('stopwords')
from nltk. corpus import stopwords
stopword=set(stopwords.words('english'))
stemmer = nltk. SnowballStemmer("english")

# %%
data = pd. read_csv("labeled_data.csv")

# %%
data
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# ...

# %%
import os
import pandas as pd
import re
import string

# Verify the directory and list files
directory = "C:/Users/suman/Documents/"
print("Current Working Directory:", os.getcwd())
print("Files in directory:", os.listdir(directory))

# Define the clean function
def clean(text):
    text = re.sub(r'https?://\S+|www.\S+', '', text)  # Use raw string literals
    text = re.sub(r'<.*?>+', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\w*\d\w*', '', text)  # Updated regex pattern to remove alphanumeric words
    text = text.split()
    text = " ".join(text)
    return text

# Adjust the file path as necessary
file_path = "C:/Users/suman/Documents/HateSpeechData.csv"  # Update with your actual file path

# Read the CSV file if it exists
if os.path.exists(file_path):
    data = pd.read_csv(file_path, on_bad_lines='skip')
    # Apply the clean function
    data["tweet"] = data["tweet"].apply(clean)
    print(data.head())
else:
    print(f"File not found: {file_path}")
# Out:
# Current Working Directory: C:\Users\suman\Contacts\hatespeechfolder\project
# Files in directory: ['automated_hate_detection_ppt[1] day2.pptx', 'c.c.jpg', 'Custom Office Templates', 'desktop.ini', 'Downloads - Shortcut.lnk', 'dq.jpg', 'gandhi.2.pdf', 'java eclipse', 'javaPractise', 'My Music', 'My Pictures', 'My Videos', 'New folder', 'New folder (2)', 'New folder (3)', 'Sathyasri Document.docx', 'Test.java', 'visiocr document.docx']
# File not found: C:/Users/suman/Documents/HateSpeechData.csv

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# Replace 'your_file.csv' with the actual path to your CSV file
file_path = 'your_file.csv'  # Change this to the correct path if necessary

# Check if the file exists at the specified path
import os
if os.path.exists(file_path):
    data = pd.read_csv(file_path)

    # Check and clean column names
    data.rename(columns=lambda x: x.strip(), inplace=True)

    # Verify the columns
    print(data.columns)

    # Ensure the 'labels' and 'tweet' columns exist
    if 'labels' in data.columns and 'tweet' in data.columns:
        x = np.array(data["tweet"])
        y = np.array(data["labels"])
        cv = CountVectorizer()
        X = cv.fit_transform(x)
    else:
        print("Required columns 'labels' or 'tweet' not found in DataFrame.")
else:
    print(f"File not found: {file_path}")
# Out:
# File not found: your_file.csv

# %%
file_path = 'C:/path/to/your_file.csv'  # Replace with the actual path
